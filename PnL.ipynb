# %%
import pandas as pd 
import csv
import numpy as np
import matplotlib.pyplot as plt

# %%
#Export pairs in the .csv file from the ADF test
with open("pnl.csv", newline='') as f:
    reader = csv.reader(f)
    pnl_aux = list(reader)
pnl_aux=pnl_aux[1:]
pnl_aux=pnl_aux[:(len(pnl_aux)-1)]

# %%
pnl=np.zeros(len(pnl_aux))
for i in range(len(pnl_aux)):
    pnl[i]=pnl_aux[i][1]
pnl=pnl[::-1]

# %%
pnl_ac=np.zeros(len(pnl)+1)
pnl_ac[0]=0
for i in range(len(pnl)):
    pnl_ac[i+1]=pnl_ac[i]+pnl[i]

# %%
plt.plot(pnl_)

# %%
plt.plot((pnl_ac/300)*100)
